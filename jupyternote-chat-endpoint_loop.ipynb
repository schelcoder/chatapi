# %%
import pandas as pd

# For a CSV file
df = pd.read_csv('../Environment_sustainability_businesses.csv', delimiter='\r')
#df = pd.read_csv('../sample.csv', delimiter='\r')

display(df)
# Out:
#                                  company
# 0            https://www.planetmark.com/
# 1                   https://www.erm.com/
# 2                https://eightversa.com/
# 3              https://www.wkcgroup.com/
# 4           https://www.bioregional.com/
# ..                                   ...
# 174               https://luminance.com/
# 175               https://recycleye.com/
# 176  https://www.carbonchain.com/contact
# 177          https://magora-systems.com/
# 178               https://www.sensat.co/
#
# [179 rows x 1 columns]

# %%
# Import openai
from openai import OpenAI


summaries = []

for row in df.itertuples():
    # Access attributes using row.column_name
    print(row.company)

    content = "can you summarize in less then 100 words does the following company do?" + row.company
 

    client = OpenAI(
        # defaults to os.environ.get("OPENAI_API_KEY")
        api_key="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",
    )

    chat_completion = client.chat.completions.create(
        messages=[
            {
                "role": "user",
                "content": content,
            }
        ],
        model="gpt-4-1106-preview",
    )

    summaries.append(chat_completion)
# Out:
# https://www.planetmark.com/
# https://www.erm.com/
# https://eightversa.com/
# https://www.wkcgroup.com/
# https://www.bioregional.com/
# https://mmenvironment.co.uk/
# https://longevity-partners.com/
# https://www.ramboll.com/
# https://www.greengage-env.com/
# https://www.triumenvironmental.co.uk/
# https://www.enhabit.uk.com/
# https://apotechconsulting.com/
# waste2es.com
# http://reducto.app
# snackgusto.com
# http://greenlife.cloud
# rebyld.co
# greenr.co.uk
# fairfoodforager.com
# qutii.org
# http://www.socotec.co.uk/
# https://www.planetmark.com/
# https://www.bioregional.com/
# https://www.ecofye.com/
# http://www.ecusltd.co.uk/
# https://www.ramboll.com/
# http://www.iesve.com/
# http://www.greenenergyconsulting.co.uk/
# http://www.enviroukconsultants.co.uk/
# http://www.safe-environment.co.uk/
# https://adeptus.co.uk/
# http://www.ac-environmental.co.uk/
# http://www.e2consultants.co.uk/
# http://www.hybrid-environmental.co.uk/
# https://completesustainability.co.uk/
# ...

# %%
print(summaries[100].choices[0].message.content)

type(summaries)
# Out:
# Nexus Energy Solutions is a UK-based company specializing in energy efficiency services for both commercial and residential properties. They offer services such as energy performance certificates (EPCs), renewable energy advice, and energy audits with the aim of helping clients reduce energy costs and carbon footprint. Additionally, they provide consultancy on energy-saving measures and assist clients in complying with government energy regulations.
# list

# %%
df = pd.DataFrame(columns=['name','summary'])

companies = pd.read_csv('../Environment_sustainability_businesses.csv', delimiter='\r')

for i in range(len(summaries)):
#for i in range(0,6):

    new_record = pd.DataFrame([{'name':companies.iloc[i,0], 'summary':summaries[i].choices[0].message.content}])
    df = pd.concat([df, new_record], ignore_index=True)

print(df)
# Out:
#                                     name  \
# 0            https://www.planetmark.com/
# 1                   https://www.erm.com/
# 2                https://eightversa.com/
# 3              https://www.wkcgroup.com/
# 4           https://www.bioregional.com/
# ..                                   ...
# 174               https://luminance.com/
# 175               https://recycleye.com/
# 176  https://www.carbonchain.com/contact
# 177          https://magora-systems.com/
# 178               https://www.sensat.co/
#
#                                                summary
# 0    Planet Mark is a sustainability certification ...
# 1    ERM (Environmental Resources Management) is a ...
# 2    Eight Versa is a Singapore-based company speci...
# 3    WKC Group is an environmental consultancy firm...
# 4    BioRegional is an entrepreneurial charity that...
# ..                                                 ...
# 174  Luminance provides artificial intelligence pla...
# ...

# %%
df.to_csv('../result2.csv')

# %%
companies = pd.read_csv('../Environment_sustainability_businesses.csv', delimiter='\r')
len(companies)
print(companies.iloc[1,0])
# Out:
# https://www.erm.com/

# %%
len(summaries)
# Out:
# 179
